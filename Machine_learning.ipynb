# %% [markdown]
# <a href="https://colab.research.google.com/github/ghanashyam1997/Machine_Learning_Basic_1/blob/main/Machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## First ML

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/dataprofessor/data/master/delaney_solubility_with_descriptors.csv")
df.head
# Out:
# <bound method NDFrame.head of       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]>

# %% [markdown]
# ## data preparation

# %% [markdown]
# ###seprate x and y values

# %%
y=df["logS"]

# %%
x=df.drop("logS", axis=1)
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %% [markdown]
# ###splitting the data to train and test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=100)
X_train
# Out:
#      MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 107  3.14280  112.216                5.0            0.000000
# 378 -2.07850  142.070                0.0            0.000000
# 529 -0.47730  168.152                0.0            0.000000
# 546 -0.86740  154.125                0.0            0.000000
# 320  1.62150  100.161                2.0            0.000000
# ..       ...      ...                ...                 ...
# 802  3.00254  250.301                1.0            0.842105
# 53   2.13860   82.146                3.0            0.000000
# 350  5.76304  256.348                0.0            0.900000
# 79   3.89960  186.339               10.0            0.000000
# 792  2.52334  310.297                3.0            0.300000
#
# [915 rows x 4 columns]

# %% [markdown]
# ##model building

# %% [markdown]
# ###linear regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #####predict with model

# %%
y_lr_train_pred=lr.predict(X_train)
y_lr_test_pred=lr.predict(X_test)
y_lr_test_pred
# Out:
# array([-3.05722870e+00, -7.77785827e+00, -2.55016650e+00, -2.01523582e+00,
#        -2.06375990e+00, -9.99672215e-01, -5.94603364e-01, -5.53626003e-01,
#        -5.72200956e+00, -3.94006681e+00, -3.95496755e+00, -2.29737009e+00,
#        -1.48980354e+00, -1.48988982e+00, -4.64510806e+00, -1.90396018e+00,
#        -1.51566313e+00, -3.16424605e+00, -3.70863920e+00, -5.58105660e+00,
#        -3.25038467e+00, -5.04235077e+00, -5.69194881e+00, -2.14339849e+00,
#        -4.35689341e+00, -5.03964756e+00, -3.10383618e+00, -4.40286964e+00,
#        -4.21276272e+00,  5.56508349e-01, -1.45537678e+00, -4.41027396e+00,
#        -2.59668773e+00, -1.53336276e+00, -5.55749874e-01, -1.67111795e+00,
#        -2.78163675e+00, -3.15395565e+00, -5.27083361e+00, -1.75321446e+00,
#        -1.53350725e+00, -2.01255666e+00, -6.57559167e+00, -7.89433046e+00,
#        -5.76437127e+00, -4.16422068e+00, -3.43694663e+00,  1.43834212e+00,
# ...

# %% [markdown]
# ####model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_per=mean_squared_error(Y_train,y_lr_train_pred)
lr_train_r2=r2_score(Y_train,y_lr_train_pred)
lr_test_per=mean_squared_error(Y_test,y_lr_test_pred)
lr_test_r2=r2_score(Y_test,y_lr_test_pred)
lr_train_per
lr_train_r2
# Out:
# 0.7645051774663391

# %% [markdown]
# #####table for linear regression results

# %%
lr_dt_frame=pd.DataFrame(["Linearregression", lr_test_per,lr_test_r2]).transpose()
lr_dt_frame.columns=["Method","MSE","Rootmeansquare"]
lr_dt_frame
# Out:
#              Method       MSE Rootmeansquare
# 0  Linearregression  1.020695       0.789162

# %% [markdown]
# ###Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(max_depth=2,random_state=100)
rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ####predict with model

# %%
y_rf_train_pred=rf.predict(X_train)
y_rf_test_pred=rf.predict(X_test)

# %% [markdown]
# ####model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score
rf_train_per=mean_squared_error(Y_train,y_rf_train_pred)
rf_train_r2=r2_score(Y_train,y_rf_train_pred)
rf_test_per=mean_squared_error(Y_test,y_rf_test_pred)
rf_test_r2=r2_score(Y_test,y_rf_test_pred)
print("mse",rf_train_per)
print("root",rf_train_r2)
# Out:
# mse 1.028227802112806
# root 0.7596688824431413

# %% [markdown]
# #####table for random forrest

# %%
rf_dt_frame=pd.DataFrame(["Randomforrest", rf_test_per,rf_test_r2]).transpose()
rf_dt_frame.columns=["Method","MSE","Rootmeansquare"]
rf_dt_frame
# Out:
#           Method       MSE Rootmeansquare
# 0  Randomforrest  1.407688       0.709223

# %% [markdown]
# ##comparison of both methods in table

# %%
ml_compare=pd.concat([lr_dt_frame, rf_dt_frame], axis=0)


ml_compare
# Out:
#              Method       MSE Rootmeansquare
# 0  Linearregression  1.020695       0.789162
# 0     Randomforrest  1.407688       0.709223
